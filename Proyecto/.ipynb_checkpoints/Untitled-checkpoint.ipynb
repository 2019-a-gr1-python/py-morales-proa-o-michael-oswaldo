# %% [markdown]
# # Proyecto

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
path = "C:/Users/MichaelDrake/Documents/GitHub/py-morales-proa-o-michael-oswaldo/04_dataFrames/data/csv/accidentes.csv"

# %%
df = pd.read_csv(
   path,
    sep = ';',
    nrows= 5
        )

# %%
pd.to_numeric(df['TOTAL_VICTIMAS'], errors='ignore')
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
# 5        1
# 6        1
# 7        0
# 8        2
# 9        1
# 10       2
# 11       0
# 12       0
# 13       1
# 14       0
# 15       0
# 16       1
# 17       0
# 18       1
# 19       0
# 20       0
# 21       1
# 22       0
# 23       1
# 24       1
# 25       0
# 26       1
# 27       1
# 28       1
# 29       2
#         ..
# 28937    2
# 28938    1
# 28939    3
# 28940    2
# 28941    2
# 28942    3
# 28943    3
# 28944    1
# 28945    0
# 28946    0
# 28947    2
# 28948    1
# 28949    0
# 28950    0
# 28951    1
# 28952    1
# 28953    1
# 28954    0
# 28955    1
# 28956    2
# 28957    2
# 28958    1
# 28959    2
# 28960    0
# 28961    0
# 28962    1
# 28963    0
# 28964    0
# 28965    1
# 28966    1
# Name: TOTAL_VICTIMAS, Length: 28967, dtype: object

# %%
df['TOTAL_VICTIMAS'].astype(float)
##df.groupby('MES')['TOTAL_VICTIMAS'].sum().plot(kind = 'bar')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-194-2407cc4e6852> in <module>
# ----> 1 df['TOTAL_VICTIMAS'].astype(float)
#       2 ##df.groupby('MES')['TOTAL_VICTIMAS'].sum().plot(kind = 'bar')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
# ...

# %%
df2 = df.fillna(method='bfill', limit=1)

# %%
df2
# Out:
#                          PROVINCIA                           CANTON  \
# 0                         COTOPAXI                        LATACUNGA
# 1                         COTOPAXI                        LATACUNGA
# 2                           MANABÍ                       PORTOVIEJO
# 3   SANTO DOMINGO DE LOS TSÁCHILAS                    SANTO DOMINGO
# 4                        PICHINCHA  DISTRITO METROPOLITANO DE QUITO
# 5                           GUAYAS                        GUAYAQUIL
# 6                         COTOPAXI                           PUJILÍ
# 7                           EL ORO                          MACHALA
# 8                       ESMERALDAS                         ATACAMES
# 9                       CHIMBORAZO                            COLTA
# 10                      ESMERALDAS                         RÍOVERDE
# 11                            LOJA                           CALVAS
# 12                      TUNGURAHUA                           AMBATO
# ...
